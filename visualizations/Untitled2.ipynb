# %%
# %matplotlib inline
import dmmodelplot as dmp
reload(dmp)
# Out:
# <module 'dmmodelplot' from 'dmmodelplot.py'>

# %%
dmp.plot_xy([250, 220, 190])

# %%
dmp.modelplot(0, 400)
# Out:
# [   0.           44.44444444   88.88888889  133.33333333  177.77777778
#   222.22222222  266.66666667  311.11111111  355.55555556  400.        ]
# [ 250.          241.63989507  221.21900392  200.11871272  190.0990647
#   196.74441378  216.35103892  237.99137723  249.60439544  244.71769017]
# <type 'numpy.ndarray'>

# %%
dmp.modelplot(0, 400, sigma_name = 'sigma_anapole')
